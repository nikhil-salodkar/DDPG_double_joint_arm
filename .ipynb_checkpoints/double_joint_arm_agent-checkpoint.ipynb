# %%
from unityagents import UnityEnvironment
import numpy as np

# select this option to load version 1 (with a single agent) of the environment
env = UnityEnvironment(file_name='/data/Reacher_One_Linux_NoVis/Reacher_One_Linux_NoVis.x86_64')

# select this option to load version 2 (with 20 agents) of the environment
# env = UnityEnvironment(file_name='/data/Reacher_Linux_NoVis/Reacher.x86_64')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 1
# Size of each action: 4
# There are 1 agents. Each observes a state with length: 33
# The state for the first agent looks like: [  0.00000000e+00  -4.00000000e+00   0.00000000e+00   1.00000000e+00
#   -0.00000000e+00  -0.00000000e+00  -4.37113883e-08   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00  -1.00000000e+01   0.00000000e+00
#    1.00000000e+00  -0.00000000e+00  -0.00000000e+00  -4.37113883e-08
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   5.75471878e+00  -1.00000000e+00
#    5.55726671e+00   0.00000000e+00   1.00000000e+00   0.00000000e+00
#   -1.68164849e-01]

# %% [markdown]
# ### Take Random Actions in the Environment
# Agent taking random actions are not able to solve the environment

# %%
env_info = env.reset(train_mode=True)[brain_name]      # reset the environment    
states = env_info.vector_observations                  # get the current state (for each agent)
scores = np.zeros(num_agents)                          # initialize the score (for each agent)
while True:
    actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
    actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
    env_info = env.step(actions)[brain_name]           # send all actions to tne environment
    next_states = env_info.vector_observations         # get next state (for each agent)
    rewards = env_info.rewards                         # get reward (for each agent)
    dones = env_info.local_done                        # see if episode finished
    scores += env_info.rewards                         # update the score (for each agent)
    states = next_states                               # roll over states to next time step
    if np.any(dones):                                  # exit loop if episode finished
        break
print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))
# Out:
# Total score (averaged over agents) this episode: 0.0

# %% [markdown]
# ### First creating models for both Actor and Critic

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
def hidden_init(layer):
    fan_in = layer.weight.data.size()[0]
    lim = 1. / np.sqrt(fan_in)
    return (-lim, lim)

# %%
class Actor(nn.Module):
    """Actor Model"""
    
    def __init__(self, state_size, action_size, seed, fc1_units=400, fc2_units=300):
        """Initialize parameters and build the model
        Params
            state_size (int) : Dimension of each state
            action_size (int) : Dimension of each action
            seed (int) : Ranom seed
            fc1 units (int) : number of nodes in first hidden layer
            fc2_units (int) : number of nodes in second hidden layer
            fc3_units (int) : number of nodes in third hidden layer
        """
        super(Actor, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fc1 = nn.Linear(state_size, fc1_units)
        self.bn1 = nn.BatchNorm1d(fc1_units)
        self.fc2 = nn.Linear(fc1_units, fc2_units)
        self.bn2 = nn.BatchNorm1d(fc2_units)
        self.fc3 = nn.Linear(fc2_units, action_size)
        self.reset_parameters()
        
    def reset_parameters(self):
        self.fc1.weight.data.uniform_(*hidden_init(self.fc1))
        self.fc2.weight.data.uniform_(*hidden_init(self.fc2))
        self.fc3.weight.data.uniform_(-3e-3, 3e-3)
        
    def forward(self, state):
        """Build an actor policy network that map states to actions"""
        x = F.relu(self.bn1(self.fc1(state)))
        x = F.relu(self.bn2(self.fc2(x)))
        return torch.tanh(self.fc3(x))

# %%
class Critic(nn.Module):
    """Critic Model"""
    def __init__(self, state_size, action_size, seed, f1_units=400, f2_units=300):
        """Initialize parameters and build the model
        Params
            state_size (int) : Dimension of each state
            action_size (int) : Dimension of each action
            seed (int) : Random seed
            f1_units (int) : number of nodes of first hidden layer
            f2_units (int) : number of nodes of second hidden layer
        """
        super(Critic, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.f1 = nn.Linear(state_size, f1_units)
        self.bn1 = nn.BatchNorm1d(f1_units)
        self.f2 = nn.Linear(f1_units+action_size, f2_units)
        self.bn2 = nn.BatchNorm1d(f2_units)
        self.f3 = nn.Linear(f2_units, 1)
        self.reset_parameters()
    
    def reset_parameters(self):
        self.f1.weight.data.uniform_(*hidden_init(self.f1))
        self.f2.weight.data.uniform_(*hidden_init(self.f2))
        self.f3.weight.data.uniform_(-3e-3, 3e-3)
        
    def forward(self, state, action):
        """Build a critic value network that maps (state, action) pairs to Q values"""
        xs = F.relu(self.bn1(self.f1(state)))
        x = torch.cat((xs, action), dim=1)
        x = F.relu(self.bn2(self.f2(x)))
        return self.f3(x)

# %% [markdown]
# ### crearing the agent

# %%
import random
import copy
from collections import namedtuple, deque
import torch.optim as optim

# %%
BUFFER_SIZE = int(1e6)  # replay buffer size
BATCH_SIZE = 256        # minibatch size
GAMMA = 0.99            # discount factor
TAU = 1e-3              # for soft update of target parameters
LR_ACTOR = 1e-3         # learning rate of the actor 
LR_CRITIC = 1e-3        # learning rate of the critic
WEIGHT_DECAY = 0  # L2 weight decay
UPDATE_EVERY = 20       # number of steps between every round of updates
N_UPDATES = 10          # number of batches in a single round of updates

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
class Agent():
    """Interacts with the environment and learns from it"""
    
    def __init__(self, state_size, action_size, random_seed):
        """Initialize an agent object
        
        Params
            state_size (int) : dimension of each state
            action_size (int) : dimension of each action
            random_seed (int) : random seed
        """
        self.state_size = state_size
        self.action_size = action_size
        self.random_seed = random_seed
        
        # Actor network along with its target network setup and actor network optimizer setup
        # target network optimization would be done in seperate way called as soft update
        self.actor_active = Actor(state_size, action_size, random_seed).to(device)
        self.actor_target = Actor(state_size, action_size, random_seed).to(device)
        self.actor_optimizer = optim.Adam(self.actor_active.parameters(), lr=LR_ACTOR)
        
        
#         # Critic network along with its target network
        self.critic_active = Critic(state_size, action_size, random_seed).to(device)
        self.critic_target = Critic(state_size, action_size, random_seed).to(device)
        self.critic_optimizer = optim.Adam(self.critic_active.parameters(), lr=LR_CRITIC, weight_decay=WEIGHT_DECAY)
        
        # Noise process
        # Noise process is used in creating exploration policy. In this case Ornstein-Uhlenbeck process is used to create noise
        self.noise = OUNoise(action_size, random_seed)
        
        # Replay Memory
        self.memory = ReplayBuffer(action_size, BUFFER_SIZE, BATCH_SIZE, random_seed)
        
        # Initialize time step
        self.t_step = 0
        
    def step_to_learn(self, state, action, reward, next_state, done):
        """Save experience in replay memory and use randomly extracted sample from buffer to learn"""
        # save the experience in buffer
        self.memory.add(state, action, reward, next_state, done)
        
        if self.t_step == 0:
        
            # learn when enough samples are available to be extracted to learn from memory
            if len(self.memory) > BATCH_SIZE:
                for i in range(N_UPDATES):
                    experiences = self.memory.sample()
                    self.learn(experiences, GAMMA)
            
    def get_action_to_take(self, state, add_noise=True):
        """Returns action to take given a state according to learned policy so far"""
    
        state = torch.from_numpy(state).float().to(device)
        self.actor_active.eval()
        with torch.no_grad():
            action = self.actor_active(state).cpu().data.numpy()
        self.actor_active.train()
        self.t_step = (self.t_step + 1) % UPDATE_EVERY
        if add_noise:
            action += self.noise.sample()
        return np.clip(action, -1, 1)
    
    def reset(self):
        self.noise.reset()
    
    def learn(self, experiences, gamma):
        """
        Update policy and value parameters using batch of experience tuples
        Q_targets = r + γ * critic_target(next_state, actor_target(next_state))
        where:
            actor_target(state) -> action
            critic_target(state, action) -> Q-value
        Params
        ======
            experiences (Tuple[torch.Tensor]): tuple of (s, a, r, s', done) tuples 
            gamma (float): discount factor
        """
        
        states, actions, rewards, next_states, dones = experiences
        
        # update the critic
        # Get predicted next-state action using the target actor network
        actions_next = self.actor_target(next_states)
        # Get q value of target action using the critic
        Q_targets_next = self.critic_target(next_states, actions_next)
        # Compute Q targets for current states (y_i)
        Q_targets = rewards + (gamma * Q_targets_next * (1 - dones))
        # Compute critic loss
        Q_expected = self.critic_active(states, actions)
        critic_loss = F.mse_loss(Q_expected, Q_targets)
        # Minimize the loss
        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        torch.nn.utils.clip_grad_norm_(self.critic_active.parameters(), 1)
        self.critic_optimizer.step()
        
        # update the actor
        # Compute actor loss
        actions_pred = self.actor_active(states)
        actor_loss = -self.critic_active(states, actions_pred).mean()
        # Minimize the loss
        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step()
        
        # Update the target networks using soft update
        self.soft_update(self.critic_active, self.critic_target, TAU)
        self.soft_update(self.actor_active, self.actor_target, TAU) 
        
    
    def soft_update(self, local_model, target_model, tau):
        """Soft update the model parameters
        θ_target = τ*θ_local + (1 - τ)*θ_target
        Params
        ======
            local_model: PyTorch model (weights will be copied from)
            target_model: PyTorch model (weights will be copied to)
            tau (float): interpolation parameter 
        """
        
        for target_param, local_param in zip(target_model.parameters(), local_model.parameters()):
            target_param.data.copy_(tau*local_param.data + (1.0-tau)*target_param.data)

# %%
class OUNoise:
    """Ornstein-Uhlenbeck process."""

    def __init__(self, size, seed, mu=0., theta=0.03, sigma=0.02):
        """Initialize parameters and noise process."""
        self.mu = mu * np.ones(size)
        self.theta = theta
        self.sigma = sigma
        self.seed = random.seed(seed)
        self.reset()

    def reset(self):
        """Reset the internal state (= noise) to mean (mu)."""
        self.state = copy.copy(self.mu)

    def sample(self):
        """Update internal state and return it as a noise sample."""
        x = self.state
        dx = self.theta * (self.mu - x) + self.sigma * np.array([random.random() for i in range(len(x))])
        self.state = x + dx
        return self.state

# %%
class ReplayBuffer:
    """Fixed-size buffer to store experience tuples."""

    def __init__(self, action_size, buffer_size, batch_size, seed):
        """Initialize a ReplayBuffer object.
        Params
        ======
            buffer_size (int): maximum size of buffer
            batch_size (int): size of each training batch
        """
        self.action_size = action_size
        self.memory = deque(maxlen=buffer_size)  # internal memory (deque)
        self.batch_size = batch_size
        self.experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])
        self.seed = random.seed(seed)
    
    def add(self, state, action, reward, next_state, done):
        """Add a new experience to memory."""
        e = self.experience(state, action, reward, next_state, done)
        self.memory.append(e)
    
    def sample(self):
        """Randomly sample a batch of experiences from memory."""
        experiences = random.sample(self.memory, k=self.batch_size)

        states = torch.from_numpy(np.vstack([e.state for e in experiences if e is not None])).float().to(device)
        actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).float().to(device)
        rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float().to(device)
        next_states = torch.from_numpy(np.vstack([e.next_state for e in experiences if e is not None])).float().to(device)
        dones = torch.from_numpy(np.vstack([e.done for e in experiences if e is not None]).astype(np.uint8)).float().to(device)

        return (states, actions, rewards, next_states, dones)

    def __len__(self):
        """Return the current size of internal memory."""
        return len(self.memory)

# %% [markdown]
# ### Train the agent by interacting with the environment

# %%
agent = Agent(state_size, action_size, 2)

# %%
def train_agent(n_episodes=500, max_t=1000):
    """Train an agent by iterating episodes"""
    checkpoint_name = 'ddpg.pth'
    mean_scores = []
    moving_avgs = []
    scores_window = deque(maxlen=100)
    printed = False
    print_every = 1
    target_score = 30
    for i_episode in range(1, n_episodes+1):
        env_info = env.reset(train_mode=True)[brain_name]
        current_state = env_info.vector_observations
        score = np.zeros(len(env_info.agents))
        agent.reset()
        for t in range(max_t):
            action = agent.get_action_to_take(current_state)      # Select an action
            env_info = env.step(action)[brain_name]               # Send the action to the environment
            next_state = env_info.vector_observations           # Get the next state from env after action taken
            reward = env_info.rewards                          # Get the reward received
            done = env_info.local_done                         # See if the episode has finished
            agent.step_to_learn(current_state, action, reward, next_state, done) # make the agent learn
            score += reward
            current_state = next_state
            if np.any(done):
                break                     
        mean_scores.append(np.mean(score))
        # append the mean score in score window
        scores_window.append(mean_scores[-1])       
        moving_avgs.append(np.mean(scores_window))    # save moving average
                
        if i_episode % print_every == 0:
            print('\rEpisode {} : \tMeanScore: {:.2f}\tMovAvg: {:.2f}'.format(\
                  i_episode, mean_scores[-1], moving_avgs[-1]))
                  
        if moving_avgs[-1] >= target_score and i_episode >= 100 and printed == False:
            print('\nEnvironment SOLVED in {} episodes!\tMoving Average ={:.2f} over last 100 episodes'.format(\
                                    i_episode, moving_avgs[-1]))
            torch.save(agent.actor_active.state_dict(), checkpoint_name)
            printed = True
    return mean_scores, moving_avgs

# %%
# for 256 batch size
scores = train_agent()
# Out:
# Episode 1 : 	MeanScore: 1.49	MovAvg: 1.49
# Episode 2 : 	MeanScore: 1.75	MovAvg: 1.62
# Episode 3 : 	MeanScore: 1.43	MovAvg: 1.56
# Episode 4 : 	MeanScore: 1.77	MovAvg: 1.61
# Episode 5 : 	MeanScore: 1.19	MovAvg: 1.53
# Episode 6 : 	MeanScore: 0.36	MovAvg: 1.33
# Episode 7 : 	MeanScore: 0.28	MovAvg: 1.18
# Episode 8 : 	MeanScore: 0.05	MovAvg: 1.04
# Episode 9 : 	MeanScore: 0.84	MovAvg: 1.02
# Episode 10 : 	MeanScore: 0.00	MovAvg: 0.92
# Episode 11 : 	MeanScore: 0.37	MovAvg: 0.87
# Episode 12 : 	MeanScore: 0.28	MovAvg: 0.82
# Episode 13 : 	MeanScore: 0.08	MovAvg: 0.76
# Episode 14 : 	MeanScore: 1.57	MovAvg: 0.82
# Episode 15 : 	MeanScore: 0.26	MovAvg: 0.78
# Episode 16 : 	MeanScore: 1.72	MovAvg: 0.84
# Episode 17 : 	MeanScore: 0.36	MovAvg: 0.81
# Episode 18 : 	MeanScore: 2.81	MovAvg: 0.92
# Episode 19 : 	MeanScore: 1.09	MovAvg: 0.93
# Episode 20 : 	MeanScore: 1.42	MovAvg: 0.96
# Episode 21 : 	MeanScore: 1.81	MovAvg: 1.00
# Episode 22 : 	MeanScore: 2.24	MovAvg: 1.05
# Episode 23 : 	MeanScore: 1.15	MovAvg: 1.06
# Episode 24 : 	MeanScore: 2.03	MovAvg: 1.10
# Episode 25 : 	MeanScore: 0.77	MovAvg: 1.08
# Episode 26 : 	MeanScore: 3.05	MovAvg: 1.16
# Episode 27 : 	MeanScore: 1.99	MovAvg: 1.19
# Episode 28 : 	MeanScore: 2.66	MovAvg: 1.24
# Episode 29 : 	MeanScore: 1.82	MovAvg: 1.26
# Episode 30 : 	MeanScore: 3.06	MovAvg: 1.32
# Episode 31 : 	MeanScore: 2.56	MovAvg: 1.36
# Episode 32 : 	MeanScore: 3.37	MovAvg: 1.43
# Episode 33 : 	MeanScore: 1.73	MovAvg: 1.44
# Episode 34 : 	MeanScore: 5.29	MovAvg: 1.55
# Episode 35 : 	MeanScore: 3.61	MovAvg: 1.61
# Episode 36 : 	MeanScore: 12.48	MovAvg: 1.91
# Episode 37 : 	MeanScore: 7.61	MovAvg: 2.06
# Episode 38 : 	MeanScore: 10.94	MovAvg: 2.30
# Episode 39 : 	MeanScore: 4.31	MovAvg: 2.35
# Episode 40 : 	MeanScore: 7.58	MovAvg: 2.48
# Episode 41 : 	MeanScore: 8.63	MovAvg: 2.63
# Episode 42 : 	MeanScore: 5.53	MovAvg: 2.70
# Episode 43 : 	MeanScore: 6.49	MovAvg: 2.79
# Episode 44 : 	MeanScore: 4.79	MovAvg: 2.83
# Episode 45 : 	MeanScore: 7.03	MovAvg: 2.93
# Episode 46 : 	MeanScore: 6.90	MovAvg: 3.01
# Episode 47 : 	MeanScore: 9.07	MovAvg: 3.14
# Episode 48 : 	MeanScore: 5.68	MovAvg: 3.19
# Episode 49 : 	MeanScore: 9.78	MovAvg: 3.33
# Episode 50 : 	MeanScore: 14.56	MovAvg: 3.55
# Episode 51 : 	MeanScore: 11.28	MovAvg: 3.70
# Episode 52 : 	MeanScore: 4.35	MovAvg: 3.72
# Episode 53 : 	MeanScore: 10.83	MovAvg: 3.85
# Episode 54 : 	MeanScore: 8.25	MovAvg: 3.93
# Episode 55 : 	MeanScore: 20.67	MovAvg: 4.24
# Episode 56 : 	MeanScore: 14.64	MovAvg: 4.42
# Episode 57 : 	MeanScore: 10.83	MovAvg: 4.53
# Episode 58 : 	MeanScore: 17.03	MovAvg: 4.75
# Episode 59 : 	MeanScore: 12.32	MovAvg: 4.88
# Episode 60 : 	MeanScore: 20.07	MovAvg: 5.13
# Episode 61 : 	MeanScore: 28.34	MovAvg: 5.51
# Episode 62 : 	MeanScore: 2.73	MovAvg: 5.47
# Episode 63 : 	MeanScore: 11.76	MovAvg: 5.57
# Episode 64 : 	MeanScore: 30.10	MovAvg: 5.95
# Episode 65 : 	MeanScore: 7.85	MovAvg: 5.98
# Episode 66 : 	MeanScore: 5.77	MovAvg: 5.98
# Episode 67 : 	MeanScore: 32.74	MovAvg: 6.38
# Episode 68 : 	MeanScore: 31.03	MovAvg: 6.74
# Episode 69 : 	MeanScore: 33.06	MovAvg: 7.12
# Episode 70 : 	MeanScore: 19.07	MovAvg: 7.29
# Episode 71 : 	MeanScore: 18.19	MovAvg: 7.44
# Episode 72 : 	MeanScore: 12.82	MovAvg: 7.52
# Episode 73 : 	MeanScore: 10.41	MovAvg: 7.56
# Episode 74 : 	MeanScore: 11.91	MovAvg: 7.62
# Episode 75 : 	MeanScore: 36.54	MovAvg: 8.00
# Episode 76 : 	MeanScore: 9.87	MovAvg: 8.03
# Episode 77 : 	MeanScore: 24.36	MovAvg: 8.24
# Episode 78 : 	MeanScore: 26.88	MovAvg: 8.48
# Episode 79 : 	MeanScore: 22.32	MovAvg: 8.65
# Episode 80 : 	MeanScore: 21.32	MovAvg: 8.81
# Episode 81 : 	MeanScore: 32.50	MovAvg: 9.10
# Episode 82 : 	MeanScore: 36.75	MovAvg: 9.44
# Episode 83 : 	MeanScore: 13.40	MovAvg: 9.49
# Episode 84 : 	MeanScore: 30.15	MovAvg: 9.74
# Episode 85 : 	MeanScore: 23.67	MovAvg: 9.90
# Episode 86 : 	MeanScore: 18.66	MovAvg: 10.00
# Episode 87 : 	MeanScore: 37.93	MovAvg: 10.32
# Episode 88 : 	MeanScore: 30.86	MovAvg: 10.56
# Episode 89 : 	MeanScore: 39.57	MovAvg: 10.88
# Episode 90 : 	MeanScore: 7.72	MovAvg: 10.85
# Episode 91 : 	MeanScore: 36.62	MovAvg: 11.13
# Episode 92 : 	MeanScore: 18.96	MovAvg: 11.21
# Episode 93 : 	MeanScore: 32.56	MovAvg: 11.44
# Episode 94 : 	MeanScore: 32.41	MovAvg: 11.67
# Episode 95 : 	MeanScore: 21.26	MovAvg: 11.77
# Episode 96 : 	MeanScore: 32.29	MovAvg: 11.98
# Episode 97 : 	MeanScore: 24.69	MovAvg: 12.11
# Episode 98 : 	MeanScore: 39.31	MovAvg: 12.39
# Episode 99 : 	MeanScore: 35.85	MovAvg: 12.63
# Episode 100 : 	MeanScore: 36.16	MovAvg: 12.86
# Episode 101 : 	MeanScore: 21.61	MovAvg: 13.06
# Episode 102 : 	MeanScore: 30.27	MovAvg: 13.35
# Episode 103 : 	MeanScore: 34.20	MovAvg: 13.68
# Episode 104 : 	MeanScore: 37.80	MovAvg: 14.04
# Episode 105 : 	MeanScore: 36.07	MovAvg: 14.39
# Episode 106 : 	MeanScore: 7.99	MovAvg: 14.46
# Episode 107 : 	MeanScore: 20.89	MovAvg: 14.67
# Episode 108 : 	MeanScore: 35.75	MovAvg: 15.03
# Episode 109 : 	MeanScore: 36.77	MovAvg: 15.38
# Episode 110 : 	MeanScore: 37.85	MovAvg: 15.76
# Episode 111 : 	MeanScore: 29.29	MovAvg: 16.05
# Episode 112 : 	MeanScore: 34.71	MovAvg: 16.40
# Episode 113 : 	MeanScore: 37.29	MovAvg: 16.77
# Episode 114 : 	MeanScore: 21.37	MovAvg: 16.97
# Episode 115 : 	MeanScore: 39.38	MovAvg: 17.36
# Episode 116 : 	MeanScore: 24.59	MovAvg: 17.59
# Episode 117 : 	MeanScore: 38.74	MovAvg: 17.97
# Episode 118 : 	MeanScore: 32.82	MovAvg: 18.27
# Episode 119 : 	MeanScore: 35.06	MovAvg: 18.61
# Episode 120 : 	MeanScore: 37.01	MovAvg: 18.97
# Episode 121 : 	MeanScore: 37.92	MovAvg: 19.33
# Episode 122 : 	MeanScore: 34.96	MovAvg: 19.65
# Episode 123 : 	MeanScore: 29.39	MovAvg: 19.94
# Episode 124 : 	MeanScore: 31.60	MovAvg: 20.23
# Episode 125 : 	MeanScore: 33.79	MovAvg: 20.56
# Episode 126 : 	MeanScore: 39.48	MovAvg: 20.93
# Episode 127 : 	MeanScore: 31.96	MovAvg: 21.23
# Episode 128 : 	MeanScore: 31.72	MovAvg: 21.52
# Episode 129 : 	MeanScore: 39.57	MovAvg: 21.90
# Episode 130 : 	MeanScore: 16.44	MovAvg: 22.03
# Episode 131 : 	MeanScore: 34.87	MovAvg: 22.35
# Episode 132 : 	MeanScore: 30.11	MovAvg: 22.62
# Episode 133 : 	MeanScore: 34.08	MovAvg: 22.94
# Episode 134 : 	MeanScore: 35.76	MovAvg: 23.25
# Episode 135 : 	MeanScore: 33.29	MovAvg: 23.54
# Episode 136 : 	MeanScore: 38.05	MovAvg: 23.80
# Episode 137 : 	MeanScore: 37.75	MovAvg: 24.10
# Episode 138 : 	MeanScore: 35.64	MovAvg: 24.35
# Episode 139 : 	MeanScore: 38.18	MovAvg: 24.69
# Episode 140 : 	MeanScore: 27.99	MovAvg: 24.89
# Episode 141 : 	MeanScore: 38.53	MovAvg: 25.19
# Episode 142 : 	MeanScore: 37.35	MovAvg: 25.51
# Episode 143 : 	MeanScore: 35.33	MovAvg: 25.80
# Episode 144 : 	MeanScore: 36.78	MovAvg: 26.12
# Episode 145 : 	MeanScore: 35.13	MovAvg: 26.40
# Episode 146 : 	MeanScore: 38.92	MovAvg: 26.72
# Episode 147 : 	MeanScore: 34.37	MovAvg: 26.97
# Episode 148 : 	MeanScore: 38.71	MovAvg: 27.30
# Episode 149 : 	MeanScore: 33.06	MovAvg: 27.53
# Episode 150 : 	MeanScore: 34.21	MovAvg: 27.73
# Episode 151 : 	MeanScore: 37.00	MovAvg: 27.99
# Episode 152 : 	MeanScore: 34.99	MovAvg: 28.29
# Episode 153 : 	MeanScore: 29.63	MovAvg: 28.48
# Episode 154 : 	MeanScore: 23.56	MovAvg: 28.64
# Episode 155 : 	MeanScore: 17.69	MovAvg: 28.61
# Episode 156 : 	MeanScore: 32.87	MovAvg: 28.79
# Episode 157 : 	MeanScore: 39.60	MovAvg: 29.08
# Episode 158 : 	MeanScore: 33.65	MovAvg: 29.24
# Episode 159 : 	MeanScore: 34.23	MovAvg: 29.46
# Episode 160 : 	MeanScore: 38.14	MovAvg: 29.64
# Episode 161 : 	MeanScore: 12.41	MovAvg: 29.48
# Episode 162 : 	MeanScore: 34.10	MovAvg: 29.80
# Episode 163 : 	MeanScore: 36.39	MovAvg: 30.04
#
# Environment SOLVED in 163 episodes!	Moving Average =30.04 over last 100 episodes
# Episode 164 : 	MeanScore: 27.74	MovAvg: 30.02
# Episode 165 : 	MeanScore: 39.39	MovAvg: 30.33
# Episode 166 : 	MeanScore: 37.22	MovAvg: 30.65
# Episode 167 : 	MeanScore: 35.49	MovAvg: 30.68
# Episode 168 : 	MeanScore: 34.41	MovAvg: 30.71
# Episode 169 : 	MeanScore: 35.53	MovAvg: 30.73
# Episode 170 : 	MeanScore: 37.60	MovAvg: 30.92
# Episode 171 : 	MeanScore: 32.24	MovAvg: 31.06
# Episode 172 : 	MeanScore: 22.89	MovAvg: 31.16
# Episode 173 : 	MeanScore: 33.08	MovAvg: 31.39
# Episode 174 : 	MeanScore: 33.79	MovAvg: 31.61
# Episode 175 : 	MeanScore: 32.32	MovAvg: 31.56
# Episode 176 : 	MeanScore: 22.54	MovAvg: 31.69
# Episode 177 : 	MeanScore: 32.07	MovAvg: 31.77
# Episode 178 : 	MeanScore: 19.94	MovAvg: 31.70
# Episode 179 : 	MeanScore: 34.96	MovAvg: 31.83
# Episode 180 : 	MeanScore: 28.49	MovAvg: 31.90
# Episode 181 : 	MeanScore: 36.84	MovAvg: 31.94
# Episode 182 : 	MeanScore: 36.75	MovAvg: 31.94
# Episode 183 : 	MeanScore: 35.03	MovAvg: 32.16
# Episode 184 : 	MeanScore: 31.52	MovAvg: 32.17
# Episode 185 : 	MeanScore: 36.65	MovAvg: 32.30
# Episode 186 : 	MeanScore: 30.30	MovAvg: 32.42
# Episode 187 : 	MeanScore: 37.69	MovAvg: 32.41
# Episode 188 : 	MeanScore: 37.08	MovAvg: 32.48
# Episode 189 : 	MeanScore: 15.66	MovAvg: 32.24
# Episode 190 : 	MeanScore: 21.21	MovAvg: 32.37
# Episode 191 : 	MeanScore: 37.66	MovAvg: 32.38
# Episode 192 : 	MeanScore: 38.23	MovAvg: 32.58
# Episode 193 : 	MeanScore: 35.83	MovAvg: 32.61
# Episode 194 : 	MeanScore: 32.23	MovAvg: 32.61
# Episode 195 : 	MeanScore: 37.05	MovAvg: 32.76
# Episode 196 : 	MeanScore: 28.29	MovAvg: 32.72
# Episode 197 : 	MeanScore: 32.63	MovAvg: 32.80
# Episode 198 : 	MeanScore: 33.63	MovAvg: 32.75
# Episode 199 : 	MeanScore: 38.63	MovAvg: 32.77
# Episode 200 : 	MeanScore: 32.90	MovAvg: 32.74
# Episode 201 : 	MeanScore: 22.53	MovAvg: 32.75
# Episode 202 : 	MeanScore: 33.97	MovAvg: 32.79
# Episode 203 : 	MeanScore: 28.07	MovAvg: 32.73
# Episode 204 : 	MeanScore: 32.12	MovAvg: 32.67
# Episode 205 : 	MeanScore: 35.34	MovAvg: 32.66
# Episode 206 : 	MeanScore: 24.66	MovAvg: 32.83
# Episode 207 : 	MeanScore: 37.46	MovAvg: 32.99
# Episode 208 : 	MeanScore: 33.11	MovAvg: 32.97
# Episode 209 : 	MeanScore: 38.01	MovAvg: 32.98
# Episode 210 : 	MeanScore: 33.61	MovAvg: 32.94
# Episode 211 : 	MeanScore: 18.53	MovAvg: 32.83
# Episode 212 : 	MeanScore: 33.80	MovAvg: 32.82
# Episode 213 : 	MeanScore: 25.19	MovAvg: 32.70
# Episode 214 : 	MeanScore: 20.21	MovAvg: 32.69
# Episode 215 : 	MeanScore: 34.43	MovAvg: 32.64
# Episode 216 : 	MeanScore: 33.06	MovAvg: 32.72
# Episode 217 : 	MeanScore: 29.98	MovAvg: 32.64
# Episode 218 : 	MeanScore: 26.83	MovAvg: 32.58
# Episode 219 : 	MeanScore: 28.52	MovAvg: 32.51
# Episode 220 : 	MeanScore: 29.80	MovAvg: 32.44
# Episode 221 : 	MeanScore: 19.73	MovAvg: 32.26
# Episode 222 : 	MeanScore: 22.87	MovAvg: 32.14
# Episode 223 : 	MeanScore: 29.51	MovAvg: 32.14
# Episode 224 : 	MeanScore: 24.66	MovAvg: 32.07
# Episode 225 : 	MeanScore: 30.76	MovAvg: 32.04
# Episode 226 : 	MeanScore: 12.12	MovAvg: 31.76
# Episode 227 : 	MeanScore: 37.33	MovAvg: 31.82
# Episode 228 : 	MeanScore: 9.25	MovAvg: 31.59
# Episode 229 : 	MeanScore: 25.42	MovAvg: 31.45
# Episode 230 : 	MeanScore: 33.56	MovAvg: 31.62
# Episode 231 : 	MeanScore: 18.41	MovAvg: 31.46
# Episode 232 : 	MeanScore: 32.26	MovAvg: 31.48
# Episode 233 : 	MeanScore: 34.80	MovAvg: 31.49
# Episode 234 : 	MeanScore: 33.23	MovAvg: 31.46
# Episode 235 : 	MeanScore: 26.60	MovAvg: 31.40
# Episode 236 : 	MeanScore: 32.80	MovAvg: 31.34
# Episode 237 : 	MeanScore: 26.37	MovAvg: 31.23
# Episode 238 : 	MeanScore: 34.38	MovAvg: 31.22
# Episode 239 : 	MeanScore: 34.89	MovAvg: 31.18
# Episode 240 : 	MeanScore: 31.08	MovAvg: 31.21
# Episode 241 : 	MeanScore: 30.70	MovAvg: 31.14
# Episode 242 : 	MeanScore: 33.34	MovAvg: 31.10
# Episode 243 : 	MeanScore: 21.27	MovAvg: 30.96
# Episode 244 : 	MeanScore: 28.09	MovAvg: 30.87
# Episode 245 : 	MeanScore: 28.41	MovAvg: 30.80
# Episode 246 : 	MeanScore: 33.18	MovAvg: 30.74
# Episode 247 : 	MeanScore: 34.70	MovAvg: 30.75
# Episode 248 : 	MeanScore: 25.26	MovAvg: 30.61
# Episode 249 : 	MeanScore: 29.09	MovAvg: 30.57
# Episode 250 : 	MeanScore: 29.12	MovAvg: 30.52
# Episode 251 : 	MeanScore: 23.91	MovAvg: 30.39
# Episode 252 : 	MeanScore: 26.88	MovAvg: 30.31
# Episode 253 : 	MeanScore: 29.26	MovAvg: 30.31
# Episode 254 : 	MeanScore: 31.45	MovAvg: 30.39
# Episode 255 : 	MeanScore: 36.51	MovAvg: 30.57
# Episode 256 : 	MeanScore: 25.91	MovAvg: 30.50
# Episode 257 : 	MeanScore: 29.82	MovAvg: 30.41
# Episode 258 : 	MeanScore: 28.88	MovAvg: 30.36
# Episode 259 : 	MeanScore: 34.12	MovAvg: 30.36
# Episode 260 : 	MeanScore: 29.77	MovAvg: 30.27
# Episode 261 : 	MeanScore: 22.67	MovAvg: 30.38
# Episode 262 : 	MeanScore: 27.85	MovAvg: 30.31
# Episode 263 : 	MeanScore: 30.62	MovAvg: 30.26
# Episode 264 : 	MeanScore: 31.22	MovAvg: 30.29
# Episode 265 : 	MeanScore: 33.40	MovAvg: 30.23
# Episode 266 : 	MeanScore: 25.94	MovAvg: 30.12
# Episode 267 : 	MeanScore: 33.76	MovAvg: 30.10
# Episode 268 : 	MeanScore: 29.83	MovAvg: 30.05
# Episode 269 : 	MeanScore: 11.14	MovAvg: 29.81
# Episode 270 : 	MeanScore: 33.09	MovAvg: 29.77
# Episode 271 : 	MeanScore: 30.88	MovAvg: 29.75
# Episode 272 : 	MeanScore: 33.58	MovAvg: 29.86
# Episode 273 : 	MeanScore: 28.28	MovAvg: 29.81
# Episode 274 : 	MeanScore: 29.52	MovAvg: 29.77
# Episode 275 : 	MeanScore: 26.75	MovAvg: 29.71
# Episode 276 : 	MeanScore: 33.28	MovAvg: 29.82
# Episode 277 : 	MeanScore: 32.83	MovAvg: 29.83
# Episode 278 : 	MeanScore: 23.81	MovAvg: 29.87
# Episode 279 : 	MeanScore: 30.22	MovAvg: 29.82
# Episode 280 : 	MeanScore: 33.32	MovAvg: 29.87
# Episode 281 : 	MeanScore: 23.73	MovAvg: 29.74
# Episode 282 : 	MeanScore: 34.40	MovAvg: 29.71
# Episode 283 : 	MeanScore: 32.47	MovAvg: 29.69
# Episode 284 : 	MeanScore: 26.99	MovAvg: 29.64
# Episode 285 : 	MeanScore: 30.33	MovAvg: 29.58
# Episode 286 : 	MeanScore: 33.02	MovAvg: 29.61
# Episode 287 : 	MeanScore: 19.31	MovAvg: 29.42
# Episode 288 : 	MeanScore: 27.59	MovAvg: 29.33
# Episode 289 : 	MeanScore: 37.46	MovAvg: 29.55
# Episode 290 : 	MeanScore: 24.66	MovAvg: 29.58
# Episode 291 : 	MeanScore: 25.53	MovAvg: 29.46
# Episode 292 : 	MeanScore: 36.00	MovAvg: 29.44
# Episode 293 : 	MeanScore: 32.57	MovAvg: 29.40
# Episode 294 : 	MeanScore: 32.48	MovAvg: 29.41
# Episode 295 : 	MeanScore: 16.99	MovAvg: 29.21
# Episode 296 : 	MeanScore: 28.72	MovAvg: 29.21
# Episode 297 : 	MeanScore: 32.64	MovAvg: 29.21
# Episode 298 : 	MeanScore: 33.32	MovAvg: 29.21
# Episode 299 : 	MeanScore: 30.70	MovAvg: 29.13
# Episode 300 : 	MeanScore: 35.19	MovAvg: 29.15
# Episode 301 : 	MeanScore: 29.91	MovAvg: 29.22
# Episode 302 : 	MeanScore: 35.78	MovAvg: 29.24
# Episode 303 : 	MeanScore: 34.81	MovAvg: 29.31
# Episode 304 : 	MeanScore: 29.66	MovAvg: 29.28
# Episode 305 : 	MeanScore: 34.15	MovAvg: 29.27
# Episode 306 : 	MeanScore: 34.58	MovAvg: 29.37
# Episode 307 : 	MeanScore: 31.37	MovAvg: 29.31
# Episode 308 : 	MeanScore: 31.59	MovAvg: 29.30
# Episode 309 : 	MeanScore: 32.78	MovAvg: 29.24
# Episode 310 : 	MeanScore: 33.86	MovAvg: 29.25
# Episode 311 : 	MeanScore: 36.99	MovAvg: 29.43
# Episode 312 : 	MeanScore: 35.78	MovAvg: 29.45
# Episode 313 : 	MeanScore: 22.07	MovAvg: 29.42
# Episode 314 : 	MeanScore: 36.35	MovAvg: 29.58
# Episode 315 : 	MeanScore: 27.96	MovAvg: 29.52
# Episode 316 : 	MeanScore: 27.28	MovAvg: 29.46
# Episode 317 : 	MeanScore: 35.81	MovAvg: 29.52
# Episode 318 : 	MeanScore: 32.38	MovAvg: 29.57
# Episode 319 : 	MeanScore: 37.08	MovAvg: 29.66
# Episode 320 : 	MeanScore: 32.21	MovAvg: 29.68
# Episode 321 : 	MeanScore: 31.30	MovAvg: 29.80
# Episode 322 : 	MeanScore: 27.00	MovAvg: 29.84
# Episode 323 : 	MeanScore: 22.69	MovAvg: 29.77
# Episode 324 : 	MeanScore: 35.71	MovAvg: 29.88
# Episode 325 : 	MeanScore: 25.09	MovAvg: 29.82
# Episode 326 : 	MeanScore: 7.53	MovAvg: 29.78
# Episode 327 : 	MeanScore: 30.15	MovAvg: 29.71
# Episode 328 : 	MeanScore: 39.19	MovAvg: 30.01
# Episode 329 : 	MeanScore: 32.21	MovAvg: 30.07
# Episode 330 : 	MeanScore: 23.23	MovAvg: 29.97
# Episode 331 : 	MeanScore: 25.16	MovAvg: 30.04
# Episode 332 : 	MeanScore: 32.53	MovAvg: 30.04
# Episode 333 : 	MeanScore: 28.10	MovAvg: 29.97
# Episode 334 : 	MeanScore: 28.83	MovAvg: 29.93
# Episode 335 : 	MeanScore: 25.48	MovAvg: 29.92
# Episode 336 : 	MeanScore: 38.05	MovAvg: 29.97
# Episode 337 : 	MeanScore: 27.16	MovAvg: 29.98
# Episode 338 : 	MeanScore: 33.89	MovAvg: 29.97
# Episode 339 : 	MeanScore: 28.79	MovAvg: 29.91
# Episode 340 : 	MeanScore: 14.47	MovAvg: 29.75
# Episode 341 : 	MeanScore: 33.44	MovAvg: 29.77
# Episode 342 : 	MeanScore: 31.40	MovAvg: 29.76
# Episode 343 : 	MeanScore: 28.91	MovAvg: 29.83
# Episode 344 : 	MeanScore: 25.49	MovAvg: 29.81
# Episode 345 : 	MeanScore: 16.60	MovAvg: 29.69
# Episode 346 : 	MeanScore: 31.80	MovAvg: 29.67
# Episode 347 : 	MeanScore: 28.03	MovAvg: 29.61
# Episode 348 : 	MeanScore: 23.23	MovAvg: 29.59
# Episode 349 : 	MeanScore: 27.32	MovAvg: 29.57
# Episode 350 : 	MeanScore: 34.09	MovAvg: 29.62
# Episode 351 : 	MeanScore: 35.02	MovAvg: 29.73
# Episode 352 : 	MeanScore: 27.44	MovAvg: 29.74
# Episode 353 : 	MeanScore: 22.64	MovAvg: 29.67
# Episode 354 : 	MeanScore: 26.43	MovAvg: 29.62
# Episode 355 : 	MeanScore: 32.32	MovAvg: 29.58
# Episode 356 : 	MeanScore: 29.00	MovAvg: 29.61
# Episode 357 : 	MeanScore: 38.02	MovAvg: 29.69
# Episode 358 : 	MeanScore: 29.48	MovAvg: 29.70
# Episode 359 : 	MeanScore: 29.57	MovAvg: 29.65
# Episode 360 : 	MeanScore: 22.32	MovAvg: 29.58
# Episode 361 : 	MeanScore: 32.65	MovAvg: 29.68
# Episode 362 : 	MeanScore: 31.95	MovAvg: 29.72
# Episode 363 : 	MeanScore: 33.95	MovAvg: 29.75
# Episode 364 : 	MeanScore: 36.28	MovAvg: 29.80
# Episode 365 : 	MeanScore: 23.42	MovAvg: 29.70
# Episode 366 : 	MeanScore: 24.34	MovAvg: 29.68
# Episode 367 : 	MeanScore: 27.28	MovAvg: 29.62
# Episode 368 : 	MeanScore: 33.14	MovAvg: 29.65
# Episode 369 : 	MeanScore: 33.83	MovAvg: 29.88
# Episode 370 : 	MeanScore: 35.24	MovAvg: 29.90
# Episode 371 : 	MeanScore: 30.02	MovAvg: 29.89
# Episode 372 : 	MeanScore: 19.38	MovAvg: 29.75
# Episode 373 : 	MeanScore: 34.71	MovAvg: 29.82
# Episode 374 : 	MeanScore: 30.85	MovAvg: 29.83
# Episode 375 : 	MeanScore: 23.68	MovAvg: 29.80
# Episode 376 : 	MeanScore: 29.40	MovAvg: 29.76
# Episode 377 : 	MeanScore: 29.57	MovAvg: 29.73
# Episode 378 : 	MeanScore: 34.78	MovAvg: 29.84
# Episode 379 : 	MeanScore: 31.52	MovAvg: 29.85
# Episode 380 : 	MeanScore: 37.92	MovAvg: 29.90
# Episode 381 : 	MeanScore: 32.59	MovAvg: 29.98
# Episode 382 : 	MeanScore: 9.98	MovAvg: 29.74
# Episode 383 : 	MeanScore: 38.86	MovAvg: 29.80
# Episode 384 : 	MeanScore: 33.46	MovAvg: 29.87
# Episode 385 : 	MeanScore: 39.58	MovAvg: 29.96
# Episode 386 : 	MeanScore: 25.32	MovAvg: 29.88
# Episode 387 : 	MeanScore: 34.41	MovAvg: 30.03
# Episode 388 : 	MeanScore: 16.85	MovAvg: 29.93
# Episode 389 : 	MeanScore: 12.98	MovAvg: 29.68
# Episode 390 : 	MeanScore: 30.51	MovAvg: 29.74
# Episode 391 : 	MeanScore: 31.25	MovAvg: 29.80
# Episode 392 : 	MeanScore: 32.17	MovAvg: 29.76
# Episode 393 : 	MeanScore: 31.41	MovAvg: 29.75
# Episode 394 : 	MeanScore: 32.22	MovAvg: 29.75
# Episode 395 : 	MeanScore: 21.89	MovAvg: 29.79
# Episode 396 : 	MeanScore: 34.78	MovAvg: 29.86
# Episode 397 : 	MeanScore: 34.33	MovAvg: 29.87
# Episode 398 : 	MeanScore: 23.60	MovAvg: 29.77
# Episode 399 : 	MeanScore: 28.48	MovAvg: 29.75
# Episode 400 : 	MeanScore: 23.19	MovAvg: 29.63
# Episode 401 : 	MeanScore: 23.27	MovAvg: 29.57
# Episode 402 : 	MeanScore: 33.76	MovAvg: 29.55
# Episode 403 : 	MeanScore: 11.88	MovAvg: 29.32
# Episode 404 : 	MeanScore: 34.07	MovAvg: 29.36
# Episode 405 : 	MeanScore: 30.81	MovAvg: 29.33
# Episode 406 : 	MeanScore: 26.72	MovAvg: 29.25
# Episode 407 : 	MeanScore: 25.28	MovAvg: 29.19
# Episode 408 : 	MeanScore: 36.38	MovAvg: 29.24
# Episode 409 : 	MeanScore: 30.41	MovAvg: 29.21
# Episode 410 : 	MeanScore: 30.37	MovAvg: 29.18
# Episode 411 : 	MeanScore: 33.62	MovAvg: 29.14
# Episode 412 : 	MeanScore: 33.51	MovAvg: 29.12
# Episode 413 : 	MeanScore: 36.02	MovAvg: 29.26
# Episode 414 : 	MeanScore: 35.08	MovAvg: 29.25
# Episode 415 : 	MeanScore: 34.74	MovAvg: 29.32
# Episode 416 : 	MeanScore: 17.54	MovAvg: 29.22
# Episode 417 : 	MeanScore: 33.12	MovAvg: 29.19
# Episode 418 : 	MeanScore: 39.08	MovAvg: 29.26
# Episode 419 : 	MeanScore: 35.57	MovAvg: 29.24
# Episode 420 : 	MeanScore: 33.00	MovAvg: 29.25
# Episode 421 : 	MeanScore: 34.67	MovAvg: 29.28
# Episode 422 : 	MeanScore: 20.55	MovAvg: 29.22
# Episode 423 : 	MeanScore: 21.91	MovAvg: 29.21
# Episode 424 : 	MeanScore: 32.95	MovAvg: 29.18
# Episode 425 : 	MeanScore: 19.58	MovAvg: 29.13
# Episode 426 : 	MeanScore: 8.97	MovAvg: 29.14
# Episode 427 : 	MeanScore: 31.16	MovAvg: 29.15
# Episode 428 : 	MeanScore: 34.72	MovAvg: 29.11
# Episode 429 : 	MeanScore: 34.25	MovAvg: 29.13
# Episode 430 : 	MeanScore: 33.73	MovAvg: 29.23
# Episode 431 : 	MeanScore: 20.89	MovAvg: 29.19
# Episode 432 : 	MeanScore: 32.40	MovAvg: 29.19
# Episode 433 : 	MeanScore: 37.04	MovAvg: 29.28
# Episode 434 : 	MeanScore: 26.88	MovAvg: 29.26
# Episode 435 : 	MeanScore: 31.73	MovAvg: 29.32
# Episode 436 : 	MeanScore: 30.66	MovAvg: 29.25
# Episode 437 : 	MeanScore: 25.66	MovAvg: 29.23
# Episode 438 : 	MeanScore: 27.60	MovAvg: 29.17
# Episode 439 : 	MeanScore: 7.30	MovAvg: 28.96
# Episode 440 : 	MeanScore: 34.54	MovAvg: 29.16
# Episode 441 : 	MeanScore: 34.17	MovAvg: 29.16
# Episode 442 : 	MeanScore: 34.05	MovAvg: 29.19
# Episode 443 : 	MeanScore: 24.88	MovAvg: 29.15
# Episode 444 : 	MeanScore: 27.19	MovAvg: 29.17
# Episode 445 : 	MeanScore: 24.75	MovAvg: 29.25
# Episode 446 : 	MeanScore: 26.86	MovAvg: 29.20
# Episode 447 : 	MeanScore: 29.00	MovAvg: 29.21
# Episode 448 : 	MeanScore: 21.71	MovAvg: 29.19
# Episode 449 : 	MeanScore: 24.29	MovAvg: 29.16
# Episode 450 : 	MeanScore: 23.22	MovAvg: 29.06
# Episode 451 : 	MeanScore: 29.20	MovAvg: 29.00
# Episode 452 : 	MeanScore: 24.23	MovAvg: 28.97
# Episode 453 : 	MeanScore: 31.51	MovAvg: 29.05
# Episode 454 : 	MeanScore: 38.21	MovAvg: 29.17
# Episode 455 : 	MeanScore: 34.47	MovAvg: 29.19
# Episode 456 : 	MeanScore: 35.77	MovAvg: 29.26
# Episode 457 : 	MeanScore: 33.79	MovAvg: 29.22
# Episode 458 : 	MeanScore: 14.06	MovAvg: 29.06
# Episode 459 : 	MeanScore: 30.04	MovAvg: 29.07
# Episode 460 : 	MeanScore: 32.59	MovAvg: 29.17
# Episode 461 : 	MeanScore: 34.69	MovAvg: 29.19
# Episode 462 : 	MeanScore: 31.50	MovAvg: 29.19
# Episode 463 : 	MeanScore: 28.25	MovAvg: 29.13
# Episode 464 : 	MeanScore: 31.90	MovAvg: 29.09
# Episode 465 : 	MeanScore: 32.09	MovAvg: 29.17
# Episode 466 : 	MeanScore: 33.42	MovAvg: 29.26
# Episode 467 : 	MeanScore: 9.86	MovAvg: 29.09
# Episode 468 : 	MeanScore: 37.24	MovAvg: 29.13
# Episode 469 : 	MeanScore: 37.47	MovAvg: 29.17
# Episode 470 : 	MeanScore: 33.48	MovAvg: 29.15
# Episode 471 : 	MeanScore: 32.60	MovAvg: 29.18
# Episode 472 : 	MeanScore: 31.54	MovAvg: 29.30
# Episode 473 : 	MeanScore: 27.45	MovAvg: 29.22
# Episode 474 : 	MeanScore: 30.27	MovAvg: 29.22
# Episode 475 : 	MeanScore: 37.42	MovAvg: 29.36
# Episode 476 : 	MeanScore: 34.09	MovAvg: 29.40
# Episode 477 : 	MeanScore: 26.81	MovAvg: 29.38
# Episode 478 : 	MeanScore: 35.23	MovAvg: 29.38
# Episode 479 : 	MeanScore: 32.79	MovAvg: 29.39
# Episode 480 : 	MeanScore: 27.57	MovAvg: 29.29
# Episode 481 : 	MeanScore: 25.48	MovAvg: 29.22
# Episode 482 : 	MeanScore: 30.59	MovAvg: 29.42
# Episode 483 : 	MeanScore: 27.07	MovAvg: 29.31
# Episode 484 : 	MeanScore: 27.27	MovAvg: 29.24
# Episode 485 : 	MeanScore: 31.27	MovAvg: 29.16
# Episode 486 : 	MeanScore: 26.48	MovAvg: 29.17
# Episode 487 : 	MeanScore: 27.93	MovAvg: 29.11
# Episode 488 : 	MeanScore: 34.36	MovAvg: 29.28
# Episode 489 : 	MeanScore: 35.94	MovAvg: 29.51
# Episode 490 : 	MeanScore: 25.76	MovAvg: 29.47
# Episode 491 : 	MeanScore: 33.36	MovAvg: 29.49
# Episode 492 : 	MeanScore: 24.35	MovAvg: 29.41
# Episode 493 : 	MeanScore: 35.22	MovAvg: 29.45
# Episode 494 : 	MeanScore: 29.23	MovAvg: 29.42
# Episode 495 : 	MeanScore: 29.33	MovAvg: 29.49
# Episode 496 : 	MeanScore: 29.80	MovAvg: 29.44
# Episode 497 : 	MeanScore: 18.62	MovAvg: 29.28
# Episode 498 : 	MeanScore: 26.47	MovAvg: 29.31
# Episode 499 : 	MeanScore: 25.13	MovAvg: 29.28
# Episode 500 : 	MeanScore: 26.91	MovAvg: 29.32

# %%
from matplotlib import pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores[0])), scores[0])
plt.title('Single Double joint agent using DDPG')
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()
